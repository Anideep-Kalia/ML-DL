# %% [markdown]
# So this is the code for using pre trained model i.e. word2vec-google-news-300 for generating the vector and training the model on data base to classify spam and ham

# %%
# !pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 8.5 MB/s  0:00:02m0:00:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [gensim]2m2/3 [gensim]
# ...

# %%
import gensim
from gensim.models import Word2Vec, KeyedVectors

# %%
import gensim.downloader as api

wv = api.load('word2vec-google-news-300')

vec_king = wv['king']
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 3
#       1 import gensim.downloader as api
# ----> 3 wv = api.load('word2vec-google-news-300')
#       5 vec_king = wv['king']
#
# File ~/Downloads/Weeknds/NLP/venv/lib/python3.11/site-packages/gensim/downloader.py:496, in load(name, return_path)
#     494 path = os.path.join(folder_dir, file_name)
#     495 if not os.path.exists(folder_dir):
# --> 496     _download(name)
#     498 if return_path:
#     499     return path
#
# File ~/Downloads/Weeknds/NLP/venv/lib/python3.11/site-packages/gensim/downloader.py:365, in _download(name)
#     363 tmp_dir = tempfile.mkdtemp()
#     364 init_path = os.path.join(tmp_dir, "__init__.py")
# --> 365 urllib.urlretrieve(url_load_file, init_path)
#     366 total_parts = _get_parts(name)
#     367 if total_parts > 1:
#
# ...

# %%
vec_king
# Out:
# array([ 1.25976562e-01,  2.97851562e-02,  8.60595703e-03,  1.39648438e-01,
#        -2.56347656e-02, -3.61328125e-02,  1.11816406e-01, -1.98242188e-01,
#         5.12695312e-02,  3.63281250e-01, -2.42187500e-01, -3.02734375e-01,
#        -1.77734375e-01, -2.49023438e-02, -1.67968750e-01, -1.69921875e-01,
#         3.46679688e-02,  5.21850586e-03,  4.63867188e-02,  1.28906250e-01,
#         1.36718750e-01,  1.12792969e-01,  5.95703125e-02,  1.36718750e-01,
#         1.01074219e-01, -1.76757812e-01, -2.51953125e-01,  5.98144531e-02,
#         3.41796875e-01, -3.11279297e-02,  1.04492188e-01,  6.17675781e-02,
#         1.24511719e-01,  4.00390625e-01, -3.22265625e-01,  8.39843750e-02,
#         3.90625000e-02,  5.85937500e-03,  7.03125000e-02,  1.72851562e-01,
#         1.38671875e-01, -2.31445312e-01,  2.83203125e-01,  1.42578125e-01,
#         3.41796875e-01, -2.39257812e-02, -1.09863281e-01,  3.32031250e-02,
# ...

# %%
import pandas as pd
messages=pd.read_csv('smsspamcollection/SMSSpamCollection',
                    sep='\t',names=["label","message"])

# %%
messages
# Out:
# "Please don't text me anymore. I have nothing else to say."

# %%
messages['message'].loc[100]

# %%
messages.shape
# Out:
# (5572, 2)

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
import re
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/anideepkalia/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
corpus = []
for i in range(0, len(messages)):
    review = re.sub('[^a-zA-Z]', ' ', messages['message'][i])
    review = review.lower()
    review = review.split()
    
    review = [lemmatizer.lemmatize(word) for word in review]
    review = ' '.join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['go until jurong point crazy available only in bugis n great world la e buffet cine there got amore wat',
#  'ok lar joking wif u oni',
#  'free entry in a wkly comp to win fa cup final tkts st may text fa to to receive entry question std txt rate t c s apply over s',
#  'u dun say so early hor u c already then say',
#  'nah i don t think he go to usf he life around here though',
#  'freemsg hey there darling it s been week s now and no word back i d like some fun you up for it still tb ok xxx std chgs to send to rcv',
#  'even my brother is not like to speak with me they treat me like aid patent',
#  'a per your request melle melle oru minnaminunginte nurungu vettam ha been set a your callertune for all caller press to copy your friend callertune',
#  'winner a a valued network customer you have been selected to receivea prize reward to claim call claim code kl valid hour only',
# ...

# %%
# creates a tuple like below
#[
#  (2, ["hello","world"], "Hello world"),
#  (0, [], "???"),
#  (1, ["nlp"], "NLP")
# ]
[[i,j,k] for i,j,k in zip(list(map(len,corpus)),corpus, messages['message']) if i<100]
# Out:
# [[23, 'ok lar joking wif u oni', 'Ok lar... Joking wif u oni...'],
#  [43,
#   'u dun say so early hor u c already then say',
#   'U dun say so early hor... U c already then say...'],
#  [57,
#   'nah i don t think he go to usf he life around here though',
#   "Nah I don't think he goes to usf, he lives around here though"],
#  [74,
#   'even my brother is not like to speak with me they treat me like aid patent',
#   'Even my brother is not like to speak with me. They treat me like aids patent.'],
#  [99,
#   'six chance to win cash from to pound txt csh and send to cost p day day tsandcs apply reply hl info',
#   'SIX chances to win CASH! From 100 to 20,000 pounds txt> CSH11 and send to 87575. Cost 150p/day, 6days, 16+ TsandCs apply Reply HL 4 info'],
#  [33,
#   'i have a date on sunday with will',
#   'I HAVE A DATE ON SUNDAY WITH WILL!!'],
#  [22, 'oh k i m watching here', "Oh k...i'm watching here:)"],
#  [74,
# ...

# %%
corpus
# Out:
# ['go until jurong point crazy available only in bugis n great world la e buffet cine there got amore wat',
#  'ok lar joking wif u oni',
#  'free entry in a wkly comp to win fa cup final tkts st may text fa to to receive entry question std txt rate t c s apply over s',
#  'u dun say so early hor u c already then say',
#  'nah i don t think he go to usf he life around here though',
#  'freemsg hey there darling it s been week s now and no word back i d like some fun you up for it still tb ok xxx std chgs to send to rcv',
#  'even my brother is not like to speak with me they treat me like aid patent',
#  'a per your request melle melle oru minnaminunginte nurungu vettam ha been set a your callertune for all caller press to copy your friend callertune',
#  'winner a a valued network customer you have been selected to receivea prize reward to claim call claim code kl valid hour only',
# ...

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
words=[]
for sent in corpus:
    sent_token=sent_tokenize(sent)
    print(sent_token)
    for sent in sent_token:
        words.append(simple_preprocess(sent))
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[23], line 3
#       1 words=[]
#       2 for sent in corpus:
# ----> 3     sent_token=sent_tokenize(sent)
#       4     print(sent_token)
#       5     for sent in sent_token:
#
# File ~/Downloads/Weeknds/NLP/venv/lib/python3.11/site-packages/nltk/tokenize/__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)    117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# File ~/Downloads/Weeknds/NLP/venv/lib/python3.11/site-packages/nltk/tokenize/__init__.py:105, in _get_punkt_tokenizer(language)
# ...

# %%
words
# Out:
# [['go',
#   'until',
#   'jurong',
#   'point',
#   'crazy',
#   'available',
#   'only',
#   'in',
#   'bugis',
#   'great',
#   'world',
#   'la',
#   'buffet',
#   'cine',
#   'there',
#   'got',
#   'amore',
#   'wat'],
#  ['ok', 'lar', 'joking', 'wif', 'oni'],
#  ['free',
#   'entry',
#   'in',
#   'wkly',
#   'comp',
#   'to',
#   'win',
#   'fa',
#   'cup',
#   'final',
#   'tkts',
#   'st',
#   'may',
#   'text',
#   'fa',
#   'to',
#   'to',
#   'receive',
#   'entry',
#   'question',
#   'std',
#   'txt',
#   'rate',
#   'apply',
#   'over'],
#  ['dun', 'say', 'so', 'early', 'hor', 'already', 'then', 'say'],
#  ['nah',
#   'don',
#   'think',
#   'he',
#   'go',
#   'to',
#   'usf',
#   'he',
#   'life',
#   'around',
#   'here',
#   'though'],
#  ['freemsg',
#   'hey',
#   'there',
#   'darling',
#   'it',
#   'been',
#   'week',
#   'now',
#   'and',
#   'no',
#   'word',
#   'back',
#   'like',
#   'some',
#   'fun',
#   'you',
#   'up',
#   'for',
#   'it',
# ...

# %%
import gensim

# %%
## Lets train Word2vec from scratch
model=gensim.models.Word2Vec(words)

# %%
## To Get All the Vocabulary
model.wv.index_to_key
# Out:
# ['to',
#  'you',
#  'the',
#  'it',
#  'and',
#  'in',
#  'is',
#  'me',
#  'my',
#  'for',
#  'your',
#  'call',
#  'of',
#  'that',
#  'have',
#  'on',
#  'now',
#  'are',
#  'can',
#  'so',
#  'but',
#  'not',
#  'or',
#  'we',
#  'do',
#  'get',
#  'at',
#  'ur',
#  'will',
#  'if',
#  'be',
#  'with',
#  'no',
#  'just',
#  'this',
#  'gt',
#  'lt',
#  'go',
#  'how',
#  'up',
#  'when',
#  'ok',
#  'day',
#  'what',
#  'free',
#  'from',
#  'all',
#  'out',
#  'know',
#  'll',
#  'come',
#  'like',
#  'good',
#  'time',
#  'am',
#  'then',
#  'got',
#  'wa',
#  'there',
#  'he',
#  'love',
#  'text',
#  'only',
#  'want',
#  'send',
#  'one',
#  'need',
#  'txt',
#  'today',
#  'by',
#  'going',
#  'don',
#  'stop',
#  'home',
#  'she',
#  'about',
#  'lor',
#  'sorry',
#  'see',
#  'still',
#  'mobile',
#  'take',
#  'back',
#  'da',
#  'reply',
#  'dont',
#  'our',
#  'think',
#  'tell',
#  'week',
#  'hi',
#  'phone',
#  'they',
#  'new',
#  'please',
#  'later',
#  'pls',
# ...

# %%
model.corpus_count
# Out:
# 5569

# %%
model.epochs
# Out:
# 5

# %%
model.wv.similar_by_word('good')
# Out:
# [('my', 0.9986233711242676),
#  ('day', 0.9984341263771057),
#  ('morning', 0.9983787536621094),
#  ('wa', 0.9983707666397095),
#  ('not', 0.9983642101287842),
#  ('well', 0.9983597993850708),
#  ('happy', 0.9982820749282837),
#  ('night', 0.9982796907424927),
#  ('very', 0.9981509447097778),
#  ('dear', 0.9981385469436646)]

# %%
model.wv['good'].shape
# Out:
# (100,)

# %%
import numpy as np
def avg_word2vec(doc):
    # averaging making nXm into nX1 by filling the vectors with average
    # model.wv[word] will give 1XD vector of that specific word and we are turning it into 1 element by taking average
    return np.mean([model.wv[word] for word in doc if word in model.wv.index_to_key],axis=0)
                #or [np.zeros(len(model.wv.index_to_key))], axis=0)

# %%
# !pip install tqdm

# %%
# for just progress bar in the terminal
from tqdm import tqdm

# %%
#apply for the entire sentences

X=[]
for i in tqdm(range(len(words))):
    X.append(avg_word2vec(words[i]))
# Out:
#   0%|                                                                                         | 0/5569 [00:00<?, ?it/s]C:\Users\win10\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\win10\anaconda3\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 100%|███████████████████████████████████████████████████████████████████████████| 5569/5569 [00:00<00:00, 10193.26it/s]

# %%
len(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 len(X)
#
# NameError: name 'X' is not defined

# %%
##independent Features
X_new=np.array(X)
# Out:
# <ipython-input-146-c24378517c84>:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   X_new=np.array(X)

# %%
messages.shape
# Out:
# (5572, 2)

# %%
X[1]
# Out:
# array([-1.93356231e-01,  2.06870615e-01,  8.65866244e-02,  9.58224237e-02,
#         7.69399405e-02, -3.98698807e-01,  1.05395772e-01,  4.14924890e-01,
#        -1.91718236e-01, -1.09027036e-01, -1.47230983e-01, -3.41823012e-01,
#        -6.78465441e-02,  7.88864195e-02,  1.66462719e-01, -1.24658264e-01,
#         9.31969061e-02, -2.84715623e-01, -3.52087431e-03, -4.92967844e-01,
#         1.51998132e-01,  8.75003263e-02,  9.82758403e-02, -1.58014327e-01,
#        -2.43601371e-02,  2.52882279e-02, -1.66070610e-01, -1.58925757e-01,
#        -1.97879627e-01,  4.81840223e-02,  2.71549881e-01,  1.90760940e-02,
#         8.39922428e-02, -1.51190266e-01, -9.77698565e-02,  3.23482841e-01,
#         6.03131205e-02, -1.12584829e-01, -9.79556665e-02, -4.00274873e-01,
#         7.30916634e-02, -1.94243461e-01, -1.80711836e-01,  9.73581523e-03,
#         1.34885401e-01, -2.19938867e-02, -1.17072053e-01, -7.56110102e-02,
# ...

# %%
X_new.shape
# Out:
# (5569,)

# %%
X_new[0].shape
# Out:
# (100,)

# %%
## Dependent Features
## Output Features
y = messages[list(map(lambda x: len(x)>0 ,corpus))]
y=pd.get_dummies(y['label'])
y=y.iloc[:,0].values

# %%
y.shape
# Out:
# (5569,)

# %%
X[0].reshape(1,-1).shape
# Out:
# (1, 100)

# %%
## this is the final independent features
df=pd.DataFrame()
for i in range(0,len(X)):
    df=df.append(pd.DataFrame(X[i].reshape(1,-1)),ignore_index=True)

# %%
df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.216207  0.239545  0.104032  0.112374  0.082477 -0.466196  0.137822
# 1 -0.193356  0.206871  0.086587  0.095822  0.076940 -0.398699  0.105396
# 2 -0.224004  0.258399  0.109422  0.132594  0.072034 -0.512921  0.139317
# 3 -0.292759  0.325016  0.135531  0.154963  0.110923 -0.622693  0.179386
# 4 -0.257790  0.268228  0.123055  0.129405  0.104291 -0.530266  0.150534
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.476254 -0.222950 -0.137382  ...  0.339254  0.194080  0.071031  0.070812
# 1  0.414925 -0.191718 -0.109027  ...  0.299242  0.157049  0.054378  0.052061
# 2  0.468239 -0.235252 -0.170547  ...  0.337649  0.206957  0.062190  0.053607
# 3  0.650676 -0.304797 -0.172119  ...  0.460873  0.255784  0.096641  0.101251
# 4  0.557835 -0.263921 -0.155187  ...  0.399028  0.217131  0.087345  0.086943
#
#          94        95        96        97        98        99
# ...

# %%
df['Output']=y

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.216207  0.239545  0.104032  0.112374  0.082477 -0.466196  0.137822
# 1 -0.193356  0.206871  0.086587  0.095822  0.076940 -0.398699  0.105396
# 2 -0.224004  0.258399  0.109422  0.132594  0.072034 -0.512921  0.139317
# 3 -0.292759  0.325016  0.135531  0.154963  0.110923 -0.622693  0.179386
# 4 -0.257790  0.268228  0.123055  0.129405  0.104291 -0.530266  0.150534
#
#           7         8         9  ...        91        92        93        94  \
# 0  0.476254 -0.222950 -0.137382  ...  0.194080  0.071031  0.070812  0.438865
# 1  0.414925 -0.191718 -0.109027  ...  0.157049  0.054378  0.052061  0.367088
# 2  0.468239 -0.235252 -0.170547  ...  0.206957  0.062190  0.053607  0.447795
# 3  0.650676 -0.304797 -0.172119  ...  0.255784  0.096641  0.101251  0.582463
# 4  0.557835 -0.263921 -0.155187  ...  0.217131  0.087345  0.086943  0.497969
#
#          95        96        97        98        99  Output
# ...

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 96        0
# 97        0
# 98        0
# 99        0
# Output    0
# Length: 101, dtype: int64

# %%
## Independent Feature
X=df

# %%
X.isnull().sum()
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 96        0
# 97        0
# 98        0
# 99        0
# Output    0
# Length: 101, dtype: int64

# %%
y=df['Output']

# %%
## Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20)

# %%
X_train.head()
# Out:
#              0         1         2         3         4         5         6  \
# 4464 -0.217020  0.255512  0.106173  0.119504  0.074694 -0.487429  0.139651
# 672  -0.244875  0.271410  0.114304  0.134989  0.089957 -0.544205  0.156727
# 359  -0.267663  0.287808  0.125663  0.134431  0.103460 -0.555823  0.162521
# 70   -0.200889  0.218030  0.097211  0.105852  0.079384 -0.435910  0.127253
# 3148 -0.196464  0.213178  0.091318  0.099782  0.073367 -0.412015  0.116882
#
#              7         8         9  ...        91        92        93  \
# 4464  0.487703 -0.226025 -0.155531  ...  0.207455  0.071450  0.063290
# 672   0.523276 -0.257568 -0.178775  ...  0.220620  0.075331  0.068684
# 359   0.577144 -0.270206 -0.162406  ...  0.238139  0.095809  0.087063
# 70    0.451032 -0.213273 -0.126732  ...  0.175443  0.068785  0.063010
# 3148  0.409727 -0.193720 -0.120134  ...  0.172275  0.066354  0.058961
#
#             94        95        96        97        98        99  Output
# ...

# %%
y_train
# Out:
# 4464    1
# 672     0
# 359     1
# 70      1
# 3148    1
#        ..
# 1758    1
# 290     1
# 1399    1
# 4683    1
# 2172    1
# Name: Output, Length: 4445, dtype: uint8

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()

# %%
classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9973021582733813

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       147
#            1       1.00      1.00      1.00       965
#
#     accuracy                           1.00      1112
#    macro avg       1.00      0.99      0.99      1112
# weighted avg       1.00      1.00      1.00      1112
